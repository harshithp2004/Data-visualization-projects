# %% [markdown]
# <a href="https://colab.research.google.com/github/harshithp2004/Data-visualization-projects/blob/main/DV_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Name:Harshith.V.Poojary
#
# Project:Analysis on World Happiness Index 2022

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
df=pd.read_csv("/content/rankings.csv")
print(df)
# Out:
#      RANK      Country  Happiness score  Whisker-high  Whisker-low  \
# 0       1      Finland            7.821         7.886        7.756
# 1       2      Denmark            7.636         7.710        7.563
# 2       3      Iceland            7.557         7.651        7.464
# 3       4  Switzerland            7.512         7.586        7.437
# 4       5  Netherlands            7.415         7.471        7.359
# ..    ...          ...              ...           ...          ...
# 141   142     Botswana            3.471         3.667        3.275
# 142   143       Rwanda            3.268         3.462        3.074
# 143   144     Zimbabwe            2.995         3.110        2.880
# 144   145      Lebanon            2.955         3.049        2.862
# 145   146  Afghanistan            2.404         2.469        2.339
#
#      Dystopia (1.83) + residual  Explained by: GDP per capita  \
# 0                         2.518                         1.892
# ...

# %%
null_values=df.isnull().sum()
print(null_values )
# Out:
# RANK                                          0
# Country                                       0
# Happiness score                               0
# Whisker-high                                  0
# Whisker-low                                   0
# Dystopia (1.83) + residual                    0
# Explained by: GDP per capita                  0
# Explained by: Social support                  0
# Explained by: Healthy life expectancy         0
# Explained by: Freedom to make life choices    0
#  Generosity                                   0
# Explained by: Perceptions of corruption       0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146 entries, 0 to 145
# Data columns (total 12 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   RANK                                        146 non-null    int64
#  1   Country                                     146 non-null    object
#  2   Happiness score                             146 non-null    float64
#  3   Whisker-high                                146 non-null    float64
#  4   Whisker-low                                 146 non-null    float64
#  5   Dystopia (1.83) + residual                  146 non-null    float64
#  6   Explained by: GDP per capita                146 non-null    float64
#  7   Explained by: Social support                146 non-null    float64
#  8   Explained by: Healthy life expectancy       146 non-null    float64
# ...

# %%
df.describe()
# Out:
#              RANK  Happiness score  Whisker-high  Whisker-low  \
# count  146.000000       146.000000    146.000000   146.000000
# mean    73.500000         5.553575      5.673589     5.433568
# std     42.290661         1.086843      1.065621     1.109380
# min      1.000000         2.404000      2.469000     2.339000
# 25%     37.250000         4.888750      5.006250     4.754750
# 50%     73.500000         5.568500      5.680000     5.453000
# 75%    109.750000         6.305000      6.448750     6.190000
# max    146.000000         7.821000      7.886000     7.756000
#
#        Dystopia (1.83) + residual  Explained by: GDP per capita  \
# count                  146.000000                    146.000000
# mean                     1.831808                      1.410445
# std                      0.534994                      0.421663
# min                      0.187000                      0.000000
# 25%                      1.555250                      1.095500
# ...

# %%
df['RANK'].value_counts()
# Out:
# 1      1
# 110    1
# 94     1
# 95     1
# 96     1
#       ..
# 50     1
# 51     1
# 52     1
# 53     1
# 146    1
# Name: RANK, Length: 146, dtype: int64

# %%
df['Country'].value_counts()
# Out:
# Cyprus         2
# Finland        1
# Mozambique     1
# Laos           1
# Algeria        1
#               ..
# Kuwait         1
# Hungary        1
# Mauritius      1
# Uzbekistan     1
# Afghanistan    1
# Name: Country, Length: 145, dtype: int64

# %%
print(df['Country'].unique())
# Out:
# ['Finland' 'Denmark' 'Iceland' 'Switzerland' 'Netherlands' 'Luxembourg'
#  'Sweden' 'Norway' 'Israel' 'New Zealand' 'Austria' 'Australia' 'Ireland'
#  'Germany' 'Canada' 'United States' 'United Kingdom' 'Czechia' 'Belgium'
#  'France' 'Bahrain' 'Slovenia' 'Costa Rica' 'United Arab Emirates'
#  'Saudi Arabia' 'Taiwan Province of China' 'Singapore' 'Romania' 'Spain'
#  'Uruguay' 'Italy' 'Kosovo' 'Malta' 'Lithuania' 'Slovakia' 'Estonia'
#  'Panama' 'Brazil' 'Guatemala' 'Kazakhstan' 'Cyprus' 'Latvia' 'Serbia'
#  'Chile' 'Nicaragua' 'Mexico' 'Croatia' 'Poland' 'El Salvador' 'Kuwait'
#  'Hungary' 'Mauritius' 'Uzbekistan' 'Japan' 'Honduras' 'Portugal'
#  'Argentina' 'Greece' 'South Korea' 'Philippines' 'Thailand' 'Moldova'
#  'Jamaica' 'Kyrgyzstan' 'Belarus' 'Colombia' 'Bosnia and Herzegovina'
#  'Mongolia' 'Dominican Republic' 'Malaysia' 'Bolivia' 'China' 'Paraguay'
#  'Peru' 'Montenegro' 'Ecuador' 'Vietnam' 'Turkmenistan' 'Russia'
# ...

# %%
print(df['Country'].nunique())
# Out:
# 145

# %%
df.corr()
# Out:
# <ipython-input-11-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                                                 RANK  Happiness score  \
# RANK                                        1.000000        -0.980856
# Happiness score                            -0.980856         1.000000
# Whisker-high                               -0.978345         0.999333
# Whisker-low                                -0.982031         0.999383
# Dystopia (1.83) + residual                 -0.444633         0.498990
# Explained by: GDP per capita               -0.792137         0.763677
# Explained by: Social support               -0.773773         0.777889
# Explained by: Healthy life expectancy      -0.750945         0.740260
# Explained by: Freedom to make life choices -0.623040         0.624822
# ...

# %%
df.groupby('Country').mean()
# Out:
#               RANK  Happiness score  Whisker-high  Whisker-low  \
# Country
# Afghanistan  146.0            2.404         2.469        2.339
# Albania       90.0            5.199         5.321        5.076
# Algeria       96.0            5.122         5.215        5.030
# Argentina     57.0            5.967         6.090        5.844
# Armenia       82.0            5.399         5.519        5.278
# ...            ...              ...           ...          ...
# Venezuela    108.0            4.925         5.051        4.800
# Vietnam       77.0            5.485         5.570        5.400
# Yemen        132.0            4.197         4.384        4.010
# Zambia       137.0            3.760         3.902        3.618
# Zimbabwe     144.0            2.995         3.110        2.880
#
#              Dystopia (1.83) + residual  Explained by: GDP per capita  \
# Country
# Afghanistan                       1.263                         0.758
# ...

# %%
pd.pivot_table(df,values='Happiness score',index='RANK',columns='Country',aggfunc='sum')
# Out:
# Country  Afghanistan  Albania  Algeria  Argentina  Armenia  Australia  \
# RANK
# 1                NaN      NaN      NaN        NaN      NaN        NaN
# 2                NaN      NaN      NaN        NaN      NaN        NaN
# 3                NaN      NaN      NaN        NaN      NaN        NaN
# 4                NaN      NaN      NaN        NaN      NaN        NaN
# 5                NaN      NaN      NaN        NaN      NaN        NaN
# ...              ...      ...      ...        ...      ...        ...
# 142              NaN      NaN      NaN        NaN      NaN        NaN
# 143              NaN      NaN      NaN        NaN      NaN        NaN
# 144              NaN      NaN      NaN        NaN      NaN        NaN
# 145              NaN      NaN      NaN        NaN      NaN        NaN
# 146            2.404      NaN      NaN        NaN      NaN        NaN
#
# Country  Austria  Azerbaijan  Bahrain  Bangladesh  ...  United Arab Emirates  \
# ...

# %%
df.sort_values('RANK',ascending=False)
# Out:
#      RANK      Country  Happiness score  Whisker-high  Whisker-low  \
# 145   146  Afghanistan            2.404         2.469        2.339
# 144   145      Lebanon            2.955         3.049        2.862
# 143   144     Zimbabwe            2.995         3.110        2.880
# 142   143       Rwanda            3.268         3.462        3.074
# 141   142     Botswana            3.471         3.667        3.275
# ..    ...          ...              ...           ...          ...
# 4       5  Netherlands            7.415         7.471        7.359
# 3       4  Switzerland            7.512         7.586        7.437
# 2       3      Iceland            7.557         7.651        7.464
# 1       2      Denmark            7.636         7.710        7.563
# 0       1      Finland            7.821         7.886        7.756
#
#      Dystopia (1.83) + residual  Explained by: GDP per capita  \
# 145                       1.263                         0.758
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
data=df['Happiness score']
mean=data.mean()
median=data.median()
mode=data.mode()[0]
std=data.std()
print (f"Mean: (mean)")
print(f"Meadian: {median}")
print (f"Mode: {mode}")
print (f"Standard deviation: (std)")
# Out:
# Mean: (mean)
# Meadian: 5.5685
# Mode: 4.516
# Standard deviation: (std)

# %% [markdown]
# Univariate Analysis

# %% [markdown]
# 1.What does the line plot of 'Happiness Score' for the top 50 countries by rank reveal about the variation in happiness scores among these countries, and are there any noticeable trends or patterns?

# %%
import matplotlib.pyplot as plt

# Assuming you have a DataFrame named 'df' with the 'Happiness score', 'Country', and 'Rank' columns
top_50_df = df[df['RANK'] <= 50]  # Select only the top 50 countries by rank
countries = top_50_df['Country']
happiness_scores = top_50_df['Happiness score']

plt.figure(figsize=(12, 6))
plt.plot(countries, happiness_scores, marker='o', linestyle='-')
plt.title('Line Plot of Happiness Score for the Top 50 Countries by Rank')
plt.xlabel('Country')
plt.ylabel('Happiness Score')
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability
plt.grid(True)
plt.show()

# %% [markdown]
# Conclusion:The line plot reveals variations in 'Happiness Score' among the top 50 ranked countries. Some exhibit stable scores, while others show fluctuations, indicating diverse happiness trends.

# %% [markdown]
# 2.What does the histogram reveal about the frequency of different happiness score ranges?

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(10,6))
sns.histplot(data,bins=4, color="skyblue", edgecolor="black")
plt.title('Happiness score')
plt.xlabel('Scores')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# Conclusion:The histogram displays the distribution of 'Happiness Score,' showing peaks in specific score ranges. This suggests that happiness scores tend to cluster around particular values, indicating potential patterns in global happiness.

# %% [markdown]
# 3.How is the density of "Explained by: Freedom to make life choices" distributed across its range

# %%
import matplotlib.pyplot as plt
import seaborn as sns

data = df['Explained by: Freedom to make life choices']
plt.figure(figsize=(8, 6))
sns.kdeplot(data,fill=True, color='skyblue')
plt.xlabel('Explained by: Freedom to make life choices')
plt.ylabel('Density')
plt.title('Density Plot of Freedom to Make Life Choices')
plt.show()

# %% [markdown]
# Conclusion:The density plot reveals the distribution of 'Explained by: Freedom to make life choices' in the dataset. It shows a peak, indicating a concentration of values, suggesting varying levels of freedom's influence on life choices across regions or countries.

# %% [markdown]
# 4.Can you analyze the distribution of 'Whisker-high' and 'Whisker-low' values using the side-by-side boxplots?

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming 'df' contains your dataset with the 'Whisker-high' and 'Whisker-low' columns
# Replace 'df' with your actual DataFrame

plt.figure(figsize=(12, 6))

# Create a subplot with two boxplots side by side
plt.subplot(1, 2, 1)
sns.boxplot(data=df, y='Whisker-high', color='lightblue')
plt.title('Boxplot of Whisker-high')
plt.ylabel('Whisker-high')

plt.subplot(1, 2, 2)
sns.boxplot(data=df, y='Whisker-low', color='lightgreen')
plt.title('Boxplot of Whisker-low')
plt.ylabel('Whisker-low')

plt.tight_layout()  # Ensure proper spacing between subplots
plt.show()

# %% [markdown]
# Conclusion:The side-by-side boxplots illustrate the distribution of 'Whisker-high' and 'Whisker-low' values, revealing differences in their variability and central tendencies. 'Whisker-high' generally exhibits higher variability, while 'Whisker-low' tends to have lower variability among the data points in the dataset.

# %% [markdown]
# 5.

# %%
import matplotlib.pyplot as plt

# Assuming you have a DataFrame called 'df' and you want to sort it by 'Explained by: GDP per capita'
sorted_df = df.sort_values(by='Explained by: GDP per capita', ascending=False)

# Select the top 20 and bottom 20 values
top_20_values = sorted_df['Explained by: GDP per capita'].head(20)
bottom_20_values = sorted_df['Explained by: GDP per capita'].tail(20)

# Create subplots for top 20 and bottom 20
fig, axes = plt.subplots(1, 2, figsize=(12, 6))

# Pie chart for top 20 countries
axes[0].pie(top_20_values, labels=top_20_values.index, autopct='%1.1f%%', shadow=True, startangle=140)
axes[0].set_title('Top 20 Countries by GDP per capita')

# Pie chart for bottom 20 countries
axes[1].pie(bottom_20_values, labels=bottom_20_values.index, autopct='%1.1f%%', shadow=True, startangle=140)
axes[1].set_title('Bottom 20 Countries by GDP per capita')

plt.show()

# %% [markdown]
# Conclusion:The pie charts provide a visual representation of the bottom 20 countries in terms of GDP per capita and Happiness score, highlighting the proportion of each country within these categories. It's evident that these countries exhibit varying degrees of economic and happiness disparities."

# %% [markdown]
# Bivariate Analysis:

# %% [markdown]
# Does a higher GDP per capita correlate with a higher happiness score?

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.scatterplot(x=df['Explained by: GDP per capita'], y=df['Happiness score'])
plt.title('Relationship between GDP per Capita and Happiness Score')
plt.xlabel('GDP per Capita')
plt.show()

# %% [markdown]
# Conclusion:The scatterplot illustrates the relationship between 'GDP per Capita' and 'Happiness Score,' showing a general positive correlation where higher GDP per capita tends to be associated with higher happiness scores. However, there are exceptions, indicating that other factors also influence happiness.

# %% [markdown]
# Is there a correlation between the level of social support and happiness?

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="darkgrid")
plt.figure(figsize=(10, 6))
sns.regplot(x=df['Explained by: Social support'], y=df['Happiness score'], scatter_kws={'alpha':0.5}, color='purple', marker='o')
plt.title('Correlation between Social Support and Happiness Score')
plt.xlabel('Social Support')
plt.ylabel('Happiness Score')
plt.show()

# %% [markdown]
# Conclusion:The scatter plot with the regression line highlights a positive correlation between 'Social Support' and 'Happiness Score,' suggesting that countries with higher social support tend to have higher happiness scores. However, there is some variability in happiness scores, indicating that other factors also play a role in overall happiness.

# %% [markdown]
# 3.How does healthy life expectancy relate to happiness?

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="white")
plt.figure(figsize=(10, 6))
sns.jointplot(x=df['Explained by: Healthy life expectancy'], y=df['Happiness score'], kind='kde', color='green', fill=True)
plt.suptitle('Impact of Healthy Life Expectancy on Happiness Score')
plt.xlabel('Healthy Life Expectancy')
plt.ylabel('Happiness Score')
plt.show()

# %% [markdown]
# Conclusion:The joint plot with a kernel density estimate (KDE) reveals the relationship between 'Healthy Life Expectancy' and 'Happiness Score,' indicating that countries with higher healthy life expectancy tend to have higher happiness scores. The KDE contour plot provides a visual representation of the density of data points in this context.

# %% [markdown]
# 4.Do countries with higher freedom scores tend to have higher happiness scores?

# %%
import seaborn as sns
import matplotlib.pyplot as plt

df_sorted = df.sort_values(by='Explained by: Freedom to make life choices', ascending=False)
top_20_values = df_sorted.head(20)
country_labels = [
    'Finland', 'Denmark', 'Iceland', 'Switzerland', 'Netherlands',
        'Luxembourg', 'Sweden', 'Norway', 'Israel', 'New Zealand',
            'Austria', 'Australia', 'Ireland', 'Germany', 'Canada',
                'United States', 'United Kingdom', 'Czechia', 'Belgium', 'France'
                ]
country_labels.reverse()
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.boxplot(x=top_20_values['Happiness score'], y=top_20_values['Explained by: Freedom to make life choices'], orient='h', palette='coolwarm')
plt.title('Freedom vs. Happiness Score (Top 20 Values)')
plt.xlabel('Happiness Score')
plt.ylabel('Country')
plt.yticks(range(20), country_labels)
plt.show()

# %% [markdown]
# Conclusion:The box plot visually compares the 'Freedom to Make Life Choices' among the top 20 countries with their respective 'Happiness Score.' It indicates variations in freedom's impact on happiness, with some countries exhibiting higher median happiness scores despite differing levels of freedom.

# %% [markdown]
# 5.Is there any relationship between Happiness score and Corruption

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Sort the DataFrame by 'Happiness score' in descending order
df_sorted = df.sort_values(by='Happiness score', ascending=False)

# Select the top 20 and bottom 20 countries
top_20_countries = df_sorted.head(20)
bottom_20_countries = df_sorted.tail(20)

# Create subplots with two rows and one column
fig, axes = plt.subplots(2, 1, figsize=(10, 12))
sns.set(style="whitegrid")

# Top 20 countries subplot
sns.scatterplot(ax=axes[0], x=top_20_countries['Happiness score'], y=top_20_countries['Explained by: Perceptions of corruption'], hue=top_20_countries['Country'], palette='Set2')
sns.kdeplot(ax=axes[0], x=top_20_countries['Happiness score'], y=top_20_countries['Explained by: Perceptions of corruption'], cmap='coolwarm', fill=True, levels=20)
axes[0].set_title('Top 20 Countries: Happiness Score vs. Perceptions of Corruption')
axes[0].set_xlabel('Happiness Score')
axes[0].set_ylabel('Perceptions of Corruption')
axes[0].legend(title='Country', loc='upper right')

# Bottom 20 countries subplot
sns.scatterplot(ax=axes[1], x=bottom_20_countries['Happiness score'], y=bottom_20_countries['Explained by: Perceptions of corruption'], hue=bottom_20_countries['Country'], palette='Set2')
sns.kdeplot(ax=axes[1], x=bottom_20_countries['Happiness score'], y=bottom_20_countries['Explained by: Perceptions of corruption'], cmap='coolwarm', fill=True, levels=20)
axes[1].set_title('Bottom 20 Countries: Happiness Score vs. Perceptions of Corruption')
axes[1].set_xlabel('Happiness Score')
axes[1].set_ylabel('Perceptions of Corruption')
axes[1].legend(title='Country', loc='upper right')

# Adjust space between subplots
plt.tight_layout()
plt.show()

# %% [markdown]
# Conclusion:The dual subplot analysis contrasts the relationship between 'Happiness Score' and 'Perceptions of Corruption' for the top 20 and bottom 20 countries. The scatterplots indicate varying associations, while the KDE plots show the distribution of data points, revealing potential patterns in how corruption perceptions affect happiness across different countries.

# %% [markdown]
# Multivariate Analysis:

# %% [markdown]
# 1.How do multiple variables collectively affect Happiness Score?

# %%
import seaborn as sns
import matplotlib.pyplot as plt

selected_columns = ['Happiness score', 'Explained by: GDP per capita', 'Explained by: Social support', 'Explained by: Healthy life expectancy']
sns.set(style='ticks')
pairplot = sns.pairplot(df[selected_columns], diag_kind='kde', height=2)
pairplot.fig.suptitle('Pairwise Relationships Among Variables', y=1.02)
pairplot.set(xlabel='X-Axis Label', ylabel='Y-Axis Label')
plt.subplots_adjust(top=0.9)
plt.show()

# %% [markdown]
# Conclusion:The pairplot displays pairwise relationships among selected variables, emphasizing the diagonal KDE plots for individual distributions and scatterplots for variable combinations. It offers insights into the distributions and potential correlations between 'Happiness Score,' 'GDP per Capita,' and 'Social Support,' highlighting any patterns or associations in the data.

# %% [markdown]
# 2.How do the distributions of selected factors compare?

# %%
import seaborn as sns
import matplotlib.pyplot as plt

selected_columns = ['Happiness score', 'Explained by: GDP per capita', 'Explained by: Social support', 'Explained by: Healthy life expectancy']

correlation_matrix = df[selected_columns].corr()

plt.figure(figsize=(10, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')

plt.title('Correlation Heatmap of Selected Variables')
plt.xlabel('Variables')
plt.ylabel('Variables')
plt.show()

# %% [markdown]
# Conclusion:The correlation heatmap visualizes the relationships among selected variables ('Happiness Score,' 'GDP per Capita,' and 'Social Support'). Strong positive correlations are evident, indicating that as 'GDP per Capita' and 'Social Support' increase, 'Happiness Score' tends to rise as well, showcasing key associations within the dataset.

# %% [markdown]
# 3.Does the "Freedom to Make Life Choices" have a relationship with "Happiness Score," and is this relationship color-coded by the level of "Social Support"?

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
scatter = plt.scatter(df['Explained by: Freedom to make life choices'],df['Happiness score'],c=df['Explained by: Social support'],cmap='viridis',alpha=0.7,label='Explained by: Social support')

plt.title('Happiness Score vs Freedom to Make Life Choices (Color-coded by Social Support)')
plt.xlabel('Explained by: Freedom to make life choices')
plt.ylabel('Happiness Score')
plt.colorbar(scatter, label='Explained by: Social support')
plt.legend()

plt.show()

# %% [markdown]
# Conclusion:The scatter plot visualizes the relationship between 'Freedom to Make Life Choices' and 'Happiness Score,' with data points color-coded by 'Social Support.' It offers insights into how freedom and social support interact to influence happiness, with varying degrees of support shaping this relationship across data points."

# %% [markdown]
# 4.How does the visual comparison of factor contributions (excluding Generosity) for the top 20 and bottom 20 ranked countries, as presented in the side-by-side stacked area plots, offer insights into the disparities and trends among these distinct groups of nations?

# %%
import matplotlib.pyplot as plt
import pandas as pd

sorted_df = df.sort_values(by="RANK")

# Select the top 20 and bottom 20 countries and relevant columns (excluding 'Generosity')
top_20_countries = sorted_df.head(20)
bottom_20_countries = sorted_df.tail(20)
selected_columns = ['Explained by: GDP per capita', 'Explained by: Social support', 'Explained by: Healthy life expectancy']

top_20_data = top_20_countries[selected_columns].T
bottom_20_data = bottom_20_countries[selected_columns].T

x_labels_top_20 = top_20_countries["Country"]
x_labels_bottom_20 = bottom_20_countries["Country"]

# Create subplots with two stack plots side by side
fig, axes = plt.subplots(1, 2, figsize=(15, 6))

# Stack plot for the top 20 countries
axes[0].stackplot(x_labels_top_20, top_20_data, labels=top_20_countries['Country'])
axes[0].set_xlabel("Country")
axes[0].set_ylabel('Contribution')
axes[0].set_title('Stack Plot of Factors for Top 20 Countries (Excluding Generosity)')
axes[0].legend(loc="upper left", bbox_to_anchor=(1, 1))
axes[0].tick_params(axis='x', rotation=45)

# Stack plot for the bottom 20 countries
axes[1].stackplot(x_labels_bottom_20, bottom_20_data, labels=bottom_20_countries["Country"])
axes[1].set_xlabel("Country")
axes[1].set_ylabel('Contribution')
axes[1].set_title('Stack Plot of Factors for Bottom 20 Countries (Excluding Generosity)')
axes[1].legend(loc="upper left", bbox_to_anchor=(1, 1))
axes[1].tick_params(axis='x', rotation=45)

plt.tight_layout()
plt.show()

# %% [markdown]
# Conclusion: The stacked area plots, showcasing factor contributions (excluding Generosity) for the top 20 and bottom 20 ranked countries. This visual comparison aids in discerning variations in influential factors between these two groups, facilitating insightful analysis of the dataset.
